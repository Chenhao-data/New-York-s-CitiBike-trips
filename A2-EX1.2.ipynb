# %% [markdown]
# # import all necessary libraries

# %%
import pandas as pd 
import numpy as np
import os 
import requests
import json
from datetime import datetime

# %% [markdown]
# # Read and join the data

# %%
folderpath = r"C:\Users\chenh\z_Careerfoundry\A2_DataVisal\Data\row data"

# %%
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
filepaths
# Out:
# ['C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202201-citibike-tripdata_1.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202201-citibike-tripdata_2.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202202-citibike-tripdata_1.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202202-citibike-tripdata_2.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202203-citibike-tripdata_1.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202203-citibike-tripdata_2.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202204-citibike-tripdata_1.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202204-citibike-tripdata_2.csv',
#  'C:\\Users\\chenh\\z_Careerfoundry\\A2_DataVisal\\Data\\row data\\202204-citibike-tripdata_3.csv',
# ...

# %%
df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# Out:
# C:\Users\chenh\AppData\Local\Temp\ipykernel_19304\1829197784.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# C:\Users\chenh\AppData\Local\Temp\ipykernel_19304\1829197784.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# C:\Users\chenh\AppData\Local\Temp\ipykernel_19304\1829197784.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# C:\Users\chenh\AppData\Local\Temp\ipykernel_19304\1829197784.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# ...

# %% [markdown]
# ## comments
# folderpath define folder's path.

# %% [markdown]
# filepath define all the files in the specific folder.

# %% [markdown]
# (pd.read_csv(f) for f in filepaths)：Iterate through the filepaths list and call pd.read_csv(f) on each file f to read each CSV file into a DataFrame.

# %% [markdown]
# pd.concat()：merge the multiple DataFrames.

# %%
df.shape
# Out:
# (29838806, 13)

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-01-21 13:22:31.463  West End Ave & W 107 St          7650.05
# 1  2022-01-10 11:41:43.422             4 Ave & 3 St          4028.04
# 2  2022-01-26 11:06:35.227          1 Ave & E 62 St          6753.08
# 3  2022-01-03 09:10:50.475          2 Ave & E 96 St          7338.02
# 4  2022-01-22 14:34:57.474          6 Ave & W 34 St          6364.10
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0  Mt Morris Park W & W 120 St        7685.14  40.802117 -73.968181
# ...

# %%
df.tail()
# Out:
#                    ride_id  rideable_type               started_at  \
# 29838801  1F223EDAFF420AE3  electric_bike  2022-12-01 20:26:45.847
# 29838802  CFA5C560ACB73B8E   classic_bike  2022-12-26 13:46:34.237
# 29838803  11C8C5E0DB947B07   classic_bike  2022-12-01 05:56:14.903
# 29838804  5B9B083C534A5964   classic_bike  2022-12-02 11:54:15.871
# 29838805  91C286C462F89A50   classic_bike  2022-12-18 13:35:22.574
#
#                          ended_at        start_station_name start_station_id  \
# 29838801  2022-12-01 20:30:46.012         Avenue D & E 3 St          5436.09
# 29838802  2022-12-26 13:52:43.900            43 Ave & 47 St          6209.05
# 29838803  2022-12-01 06:06:10.357         Avenue D & E 3 St          5436.09
# 29838804  2022-12-02 12:01:00.747  Montague St & Clinton St          4677.06
# 29838805  2022-12-18 13:37:27.193  Montague St & Clinton St          4677.06
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# ...

# %% [markdown]
# # Get weather data using NOAA's API

# %%
Token = 'OITybtVyCRUuKHxlEGTnanvpZIMQdoQT'

# %%
r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00014732&startdate=2022-01-01&enddate=2022-12-31', headers={'token':Token})

# %%
d = json.loads(r.text)

# %%
d
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 14},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': -27},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 49},
#   {'date': '2022-01-07T00:00:00',
# ...

# %%
avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']

# %%
dates_temp = [item['date'] for item in avg_temps]

# %%
temps = [item['value'] for item in avg_temps]

# %%
df_temp = pd.DataFrame()

# %%
df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %% [markdown]
# # Merge the weather data

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
df['started_at'] = pd.to_datetime(df['started_at'])
df['started_at'] = df['started_at'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df['ended_at'] = pd.to_datetime(df['ended_at'])
df['ended_at'] = df['ended_at'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  BFD29218AB271154  electric_bike  2022-01-21 13:13:43  2022-01-21 13:22:31
# 1  7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54  2022-01-10 11:41:43
# 2  95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43  2022-01-26 11:06:35
# 3  F853B50772137378   classic_bike  2022-01-03 08:35:48  2022-01-03 09:10:50
# 4  7590ADF834797B4B   classic_bike  2022-01-22 14:14:23  2022-01-22 14:34:57
#
#         start_station_name start_station_id             end_station_name  \
# 0  West End Ave & W 107 St          7650.05  Mt Morris Park W & W 120 St
# 1             4 Ave & 3 St          4028.04      Boerum Pl\t& Pacific St
# 2          1 Ave & E 62 St          6753.08              5 Ave & E 29 St
# 3          2 Ave & E 96 St          7338.02              5 Ave & E 29 St
# 4          6 Ave & W 34 St          6364.10              5 Ave & E 29 St
#
# ...

# %%
df['started_at'] = pd.to_datetime(df['started_at'], errors='coerce')
df['date'] = df['started_at'].dt.date

# %%
df.head()
# Out:
#             ride_id  rideable_type          started_at             ended_at  \
# 0  BFD29218AB271154  electric_bike 2022-01-21 13:13:43  2022-01-21 13:22:31
# 1  7C953F2FD7BE1302   classic_bike 2022-01-10 11:30:54  2022-01-10 11:41:43
# 2  95893ABD40CED4B8  electric_bike 2022-01-26 10:52:43  2022-01-26 11:06:35
# 3  F853B50772137378   classic_bike 2022-01-03 08:35:48  2022-01-03 09:10:50
# 4  7590ADF834797B4B   classic_bike 2022-01-22 14:14:23  2022-01-22 14:34:57
#
#         start_station_name start_station_id             end_station_name  \
# 0  West End Ave & W 107 St          7650.05  Mt Morris Park W & W 120 St
# 1             4 Ave & 3 St          4028.04      Boerum Pl\t& Pacific St
# 2          1 Ave & E 62 St          6753.08              5 Ave & E 29 St
# 3          2 Ave & E 96 St          7338.02              5 Ave & E 29 St
# 4          6 Ave & W 34 St          6364.10              5 Ave & E 29 St
#
# ...

# %%
df = df.sort_values(by='started_at', ascending=True)

# %%
df.head()
# Out:
#                    ride_id  rideable_type          started_at  \
# 7012723   34BD74D84D320CF5  electric_bike 2021-01-30 17:30:45
# 16758689  FA436228F4CD7647   classic_bike 2021-02-15 14:11:20
# 10829245  8FC77EAE2C0561E4   classic_bike 2021-03-11 22:08:54
# 2167335   BF45D1E037463AA8   classic_bike 2021-03-14 18:17:59
# 21775695  763D82F8CFA1D9D1   classic_bike 2021-03-31 15:35:20
#
#                      ended_at                   start_station_name  \
# 7012723   2022-05-23 06:17:27  W 144 St & Adam Clayton Powell Blvd
# 16758689  2022-08-10 15:01:30                   Kent Ave & S 11 St
# 10829245  2022-06-16 09:12:21                     Union St & 4 Ave
# 2167335   2022-02-02 23:38:01                N 12 St & Bedford Ave
# 21775695  2022-09-25 14:33:21             Willoughby St & Fleet St
#
#          start_station_id                    end_station_name end_station_id  \
# 7012723            7932.1  Frederick Douglass Blvd & W 112 St        7631.23
# ...

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df_2022 = df[df['date'].dt.year == 2022]

# %%
df_2022.head()
# Out:
#                  ride_id  rideable_type          started_at  \
# 60307   88237B34DAFDB069  electric_bike 2022-01-01 00:00:13
# 868602  4545E384F601A7E9   classic_bike 2022-01-01 00:00:32
# 686929  7CE9B56332A37463  electric_bike 2022-01-01 00:00:42
# 836043  4012D0DCF0DECD64   classic_bike 2022-01-01 00:00:44
# 521658  AEAF2FFEBB00845B  electric_bike 2022-01-01 00:00:50
#
#                    ended_at      start_station_name start_station_id  \
# 60307   2022-01-01 00:30:28     Broadway & W 160 St          8157.06
# 868602  2022-01-01 00:02:15  Forsyth St & Broome St          5453.05
# 686929  2022-01-01 00:11:38  Myrtle Ave & Marcy Ave          4707.03
# 836043  2022-01-02 01:00:38        W 43 St & 10 Ave          6756.01
# 521658  2022-01-01 02:39:37         W 15 St & 7 Ave          6030.06
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 60307        Broadway & W 160 St        8157.06  40.835775 -73.943400
# ...

# %%
# %%time
df_merged = df_2022.merge(df_temp, how = 'left', on = 'date', indicator = True)
# Out:
# CPU times: total: 25.3 s
# Wall time: 25.4 s

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type          started_at             ended_at  \
# 0  88237B34DAFDB069  electric_bike 2022-01-01 00:00:13  2022-01-01 00:30:28
# 1  4545E384F601A7E9   classic_bike 2022-01-01 00:00:32  2022-01-01 00:02:15
# 2  7CE9B56332A37463  electric_bike 2022-01-01 00:00:42  2022-01-01 00:11:38
# 3  4012D0DCF0DECD64   classic_bike 2022-01-01 00:00:44  2022-01-02 01:00:38
# 4  AEAF2FFEBB00845B  electric_bike 2022-01-01 00:00:50  2022-01-01 02:39:37
#
#        start_station_name start_station_id          end_station_name  \
# 0     Broadway & W 160 St          8157.06       Broadway & W 160 St
# 1  Forsyth St & Broome St          5453.05    Forsyth St & Broome St
# 2  Myrtle Ave & Marcy Ave          4707.03  Willoughby St & Fleet St
# 3        W 43 St & 10 Ave          6756.01                       NaN
# 4         W 15 St & 7 Ave          6030.06           W 33 St & 7 Ave
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# ...

# %%
df_merged.to_csv(r'C:\Users\chenh\z_Careerfoundry\A2_DataVisal\Data\Processed data.NewYorkbike.csv')
